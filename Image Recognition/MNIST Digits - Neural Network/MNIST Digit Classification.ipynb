# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn

# %% [markdown]
# The MNIST handrwitten digits dataset is a standard introductory dataset for classification, computer vision, and deep learning.

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
# Loading the MNIST dataset
import keras 
from keras.datasets import mnist
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# This tells us that we have 60000 images and they are 28 by 28.

# %%
y_train.shape
# Out:
# (60000,)

# %%
# display a few of the images
fig=plt.figure(figsize=(12, 12))
n_columns = 4
n_rows = 5
for i in range(1, n_columns * n_rows + 1):
    img = x_train[i]
    fig.add_subplot(n_rows, n_columns, i)
    plt.imshow(img)
plt.show()

# %%
plt.imshow(x_train[1])

# %%
plt.imshow(x_train[2])

# %%
# To instead display as a black and white image
fig=plt.figure(figsize=(12, 12))
n_columns = 4
n_rows = 5
for i in range(1, n_columns * n_rows + 1):
    img = x_train[i]
    fig.add_subplot(n_rows, n_columns, i)
    plt.imshow(img, cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# Normalizing the data, or changing the pixel values to be scaled between 0 and 1, has a significant on the model's ability to learn. You can see this by commenting these lines out later.

# %%
# normalize the data
x_train = keras.utils.normalize(x_train, axis=1)
x_test = keras.utils.normalize(x_test, axis=1)

# %%
keras.layers.Flatten(input_shape=(28, 28))
